# %%
def mcCulloch_pitts(x1,x2,w1,w2,theta):
    y=[]
    for i in range(len(x1)):
        curr_y=w1*x1[i]+w2*x2[i]
        y.append(activation(curr_y,theta))
    return y

# %%
def activation(y_in,theta):
    if y_in>=theta:
        return 1
    else: 
        return 0

# %%
#AND
x1=[0,0,1,1]
x2=[0,1,0,1]
y_op=[0,0,0,1]
w1=1
w2=1
theta=2
y=mcCulloch_pitts(x1,x2,w1,w2,theta)

# %%
print(y)
# Out:
# [0, 0, 0, 1]
